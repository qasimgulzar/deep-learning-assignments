# %%
import keras
import cv2
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import display, Image
from keras.layers import Activation
from keras.layers.convolutional import Convolution2D
from keras.models import Sequential
# %matplotlib inline
from PIL import Image

# %%
im_path='data/suzuki-baleno.JPG'
img=cv2.imread(im_path)
plt.imshow(img)

# %%
model = Sequential()
model.add(Convolution2D(32, 3, 3, activation='relu',input_shape=(600,800,1),name='first_conv_layer'))
print(model.input_shape)
# Out:
# (None, 600, 800, 1)
# /Users/qasimkhokhar/Documents/workspace/deep-learning-assignments/.venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), activation="relu", input_shape=(600, 800,..., name="first_conv_layer")`

# %%
batch=img.reshape((-1,600,800,1))
predictions = model.predict(batch)
print(predictions.shape)
# Out:
# (3, 598, 798, 32)

# %%
for i in range(predictions.shape[0]):
    plt.imshow(predictions[i].reshape((32,598,798))[0])
